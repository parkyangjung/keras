# %% [markdown]
# ### 한글 텍스트 처리
# - 형태소 분석(morphsical analysis) 의 이해, 한국어는 조사가 복잡하여 영어와 달리 텍스트처리가 어렵다
# - 형태소 분석이란 일반 문장을 "형태소"라는 최소 단위로 나누고 품사를 구분하는 작업
# - 파이선용 형태소 라이브러리는 KoNLPy이다 (이중에 Twitter 형태소 분석기가 널리 사용된다)

# %% [markdown]
# - kkma():꼬꼬마세종말뭉치 형태소분석: http://kkma.snu.ac.kr/
# - Hannanum(): 한나눔: http://semanticweb.kaist.ac.kr/hannanum/index.html
# - Twitter() : https://github.com/twitter/twitter-korean-text/
#
# - 매소드예) :morphs_(형태소추출), nouns(명사추출), pos태깅

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from sklearn.decomposition import LatentDirichletAllocation
lda = LatentDirichletAllocation?

# %%
lda = LatentDirichletAllocation

# %%
lda = LatentDirichletAllocation

# %%
lda = LatentDirichletAllocation

# %%
# !pip install konlpy

# %%
from konlpy.tag import Twitter
twitter = Twitter()
result = twitter.pos("오늘도 좋은 아침입니다", norm="True") # 정규화
print(result)
# Out:
# [('오늘', 'Noun'), ('도', 'Josa'), ('좋', 'Adjective'), ('은', 'Eomi'), ('아침', 'Noun'), ('입니', 'Adjective'), ('다', 'Eomi')]

# %%
result = twitter.pos("오늘도 좋은 아침입니다", stem="True") # 어근만 표시
print(result)
# Out:
# [('오늘', 'Noun'), ('도', 'Josa'), ('좋다', 'Adjective'), ('아침', 'Noun'), ('이다', 'Adjective')]

# %%
result = twitter.pos("아버지가방에들어가신다", stem="True") # 어근만 표시
print(result)
# Out:
# [('아버지', 'Noun'), ('가방', 'Noun'), ('에', 'Josa'), ('들어가다', 'Verb')]

# %% [markdown]
# - 국립국어원 언어 정보 나눔터 데이터 베이스
# - 토지 전자파일을 다운로드 받는다 "BEXX0004.txt"

# %%
import codecs
from bs4 import BeautifulSoup
from konlpy.tag import Twitter

# %%
# 토지 파일 열기
fp = codecs.open("data/BEXX0004.txt", "r", encoding="utf-8")
soup = BeautifulSoup(fp, "html.parser")
body = soup.select_one("body > text")
text = body.getText()

# %%
twitter = Twitter()
word_dic = {}
lines = text.split("\n")
for line in lines:
    malist = twitter.pos(line)
    for word in malist:
        if word[1] == "Noun":
            if not (word[0] in word_dic):
                word_dic[word[0]] = 0
            word_dic[word[0]] += 1

# %%
word_dic.items()
# Out:
# dict_items([('제', 211), ('편', 19), ('만세', 40), ('이후', 1), ('장', 116), ('끈', 15), ('연', 10), ('종로', 1), ('거리', 95), ('허둥지둥', 11), ('억쇠', 37), ('점포', 1), ('문', 73), ('것', 1959), ('새삼', 15), ('참말', 46), ('가게', 24), ('구마', 30), ('어젯밤', 4), ('여관', 18), ('얘기', 193), ('호', 8), ('서울', 72), ('상점', 2), ('일제', 6), ('갑자기', 33), ('맥', 10), ('어디', 133), ('자신', 165), ('가야', 28), ('알', 124), ('수', 363), ('깨', 11), ('괴', 6), ('나리', 10), ('봇짐', 6), ('엉덩이', 7), ('손', 147), ('우두커니', 17), ('길', 129), ('건너편', 4), ('상현', 289), ('반백', 5), ('맨', 22), ('상투', 7), ('집', 312), ('오래', 16), ('무명', 10), ('바지', 20), ('저고리', 35), ('땟국', 1), ('울상', 3), ('얼굴', 334), ('걸레', 3), ('전차', 5), ('땡땡', 6), ('종', 10), ('지난', 25), ('삼월', 11), ('경전', 2), ('종업원', 1), ('파업', 3), ('운행', 1), ('중지', 1), ('그', 957), ('무렵', 10), ('상가', 4), ('달', 28), ('동맹', 2), ('철시', 3), ('를', 20), ('지금', 118), ('시월', 4), ('맘', 27), ('돈', 220), ('무서븐', 4), ('장사꾼', 7), ('마다', 2), ('장시', 2), ('안', 594), ('나라', 38), ('겄', 68), ('그거', 67), ('데', 129), ('독립
# ...

# %%
keys = sorted(word_dic.items(), key=lambda x:x[1], reverse=True)
for word, count in keys[:50]:
    print("{0}({1}) ".format(word, count), end="")
print()
# Out:
# 것(1959) 그(957) 말(877) 사람(649) 안(594) 내(442) 놈(414) 일(372) 수(363) 생각(338) 얼굴(334) 나(318) 집(312) 이(303) 상현(289) 때(286) 홍(280) 거(262) 못(243) 일이(240) 소리(225) 돈(220) 여자(219) 눈(212) 제(211) 곳(211) 우리(205) 좀(201) 니(200) 한복(196) 석(194) 얘기(193) 또(193) 와(186) 술(186) 그것(184) 조준(183) 명(175) 구(173) 자신(165) 만(158) 하나(155) 서희(155) 댁(150) 더(150) 게(149) 듯(148) 때문(148) 손(147) 두(138)
