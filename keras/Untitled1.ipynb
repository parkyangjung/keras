# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (2.21.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests) (2019.6.16)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests) (3.0.4)

# %%
import requests as req
from bs4 import BeautifulSoup as bs

# %%
url = 'http://www.gwnu.ac.kr/kor/163/subview.do'

# %%
res = req.get(url)
soup = bs(res.text, 'lxml')
a = soup.find_all('div', class_='ceoGreeting')

# %%
# scripts = soup.find_all('script')

# %%
# import pandas as pd
# b = pd.DataFrame(a)

# %%
text = a[0].text.strip()

# %%
text
# Out:
# '강릉원주대학교를 방문해 주신 여러분을 진심으로 환영합니다.\n강릉원주대학교 총장 반선섭입니다.\n개교 70년의 전통을 자랑하는 강릉원주학교는 자유·진리·창조의 교훈 아래, 강릉과 원주 2개의 캠퍼스와 380여명의 교수진, 300여명의 직원, 8100여명의 재학생이 혼연일체 되어 내실 있는 대학으로 발전하고 있습니다. 특히 2007년 원주대학과의 통합을 계기로 환동해권의 중심대학을 뛰어넘어 우리나라 중부권 핵심대학으로 발 돋움하고 있습니다.\n끊임없는 변화의 노력으로 알찬 국립대학교를 만들어갑니다.\n우리 대학은 대학교육협의회에서 발표하는‘2018년 국·공립대학교 주요 공시지표’가운데 28개교의 국·공립대학교 중 전임교원 1인당 저역서 실적 1위, 전임교원 1인당 학생수 5위, 기숙사 수용률 6위, 학생 1인당 장서수 6위, 전임교원 확보율 9위에 기록 되는 등 내실을 기하며 알차게 발전하는 대학입니다.\n지역 발전과 지역인재 양성을 선도하기 위해 산학협력을 강화하고 있습니다.\n2012년부터 5년차 사업인 산학협력선도대학육성사업단을 성공적으로 운영한 바 있으며, 2017년부터 그 후속사업인 사회맞춤형산학협력선도대학사업단(LINC+)을 운영하고 있습니다. 2012년부터 10년간 재정지원을 받는 2단계 공학교육혁신센터 지원 사업 선정, 2014년 국립대학육성 사업에 선정, 특히 2018년 2주기 대학기본역량진단에서 자율개선대학으로 선정되었습니다. 이를 통해 우리 대학교는 맞춤형 산학협력, 대학재정 자립도 제고, 학생교육 수월성 확보에 이바지하고 있습니다.\n창의적 학문 연구와 인간 존중 교육으로 참된 지성인을 기릅니다.\n강릉원주대학교는 창의적 학문 연구와 인간 존중 교육을 통해 역량과 인성을 갖춘 인재를 양성하고 지역발전을 견인하여 국가와 인류에 공헌함을 최고의 사명으로 여기고 있습니다. 대학은 교육은 전공교육뿐만 아니라, 올바른 인성을 길러내는 교육이 매우 중요합니다. 우리대학은 전공교육 이외에도 비교과교육을 내실 있게 편성하여 역량과 인성을 갖추고 미래의 꿈을 향해 도전하는 참된 지성인을 양성하는데 역량을 집중하고 있습니다.\n강릉원주대학교의 중심은 학생입니다.\n자랑스러운 대학! 행복한 학생!강릉원주인의 꿈이 더 넓은 세계와 만나도록, 강릉원주인의 열정이 더 밝은 미래와 마주하도록 강릉원주대학이 함께 하겠습니다.\n감사합니다.'

# %%
pip install konlpy
# Out:
# Collecting konlpy
#   Downloading https://files.pythonhosted.org/packages/e5/3d/4e983cd98d87b50b2ab0387d73fa946f745aa8164e8888a714d5129f9765/konlpy-0.5.1-py2.py3-none-any.whl (19.4MB)
#      |████████████████████████████████| 19.4MB 2.8MB/s
# Collecting JPype1>=0.5.7 (from konlpy)
#   Downloading https://files.pythonhosted.org/packages/07/09/e19ce27d41d4f66d73ac5b6c6a188c51b506f56c7bfbe6c1491db2d15995/JPype1-0.7.0-cp36-cp36m-manylinux2010_x86_64.whl (2.7MB)
#      |████████████████████████████████| 2.7MB 34.1MB/s
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-0.7.0 konlpy-0.5.1

# %%
import nltk

# %%
from konlpy.tag import Twitter

# %%
t = Twitter()
# Out:
# /usr/local/lib/python3.6/dist-packages/konlpy/tag/_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')
# /usr/local/lib/python3.6/dist-packages/jpype/_core.py:210: UserWarning:
# -------------------------------------------------------------------------------
# Deprecated: convertStrings was not specified when starting the JVM. The default
# behavior in JPype will be False starting in JPype 0.8. The recommended setting
# for new code is convertStrings=False.  The legacy value of True was assumed for
# this session. If you are a user of an application that reported this warning,
# please file a ticket with the developer.
# -------------------------------------------------------------------------------
#
#   """)

# %%
t.pos(text)
# Out:
# [('강릉원주대', 'Noun'),
#  ('학교', 'Noun'),
#  ('를', 'Josa'),
#  ('방문', 'Noun'),
#  ('해', 'Verb'),
#  ('주신', 'Noun'),
#  ('여러분', 'Noun'),
#  ('을', 'Josa'),
#  ('진심', 'Noun'),
#  ('으로', 'Josa'),
#  ('환영', 'Noun'),
#  ('합니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('강릉원주대', 'Noun'),
#  ('학교', 'Noun'),
#  ('총장', 'Noun'),
#  ('반선', 'Noun'),
#  ('섭입', 'Noun'),
#  ('니', 'Noun'),
#  ('다', 'Josa'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('개교', 'Noun'),
#  ('70년', 'Number'),
#  ('의', 'Foreign'),
#  ('전통', 'Noun'),
#  ('을', 'Josa'),
#  ('자랑', 'Noun'),
#  ('하는', 'Verb'),
#  ('강릉', 'Noun'),
#  ('원', 'Modifier'),
#  ('주', 'Modifier'),
#  ('학교', 'Noun'),
#  ('는', 'Josa'),
#  ('자유', 'Noun'),
#  ('·', 'Punctuation'),
#  ('진리', 'Noun'),
#  ('·', 'Punctuation'),
#  ('창조', 'Noun'),
#  ('의', 'Josa'),
#  ('교훈', 'Noun'),
#  ('아래', 'Noun'),
#  (',', 'Punctuation'),
#  ('강릉', 'Noun'),
#  ('과', 'Josa'),
#  ('원주', 'Noun'),
#  ('2', 'Number'),
#  ('개', 'Noun'),
#  ('의', 'Josa'),
#  ('캠퍼스', 'Noun'),
#  ('와', 'Josa'),
#  ('380', 'Number'),
#  ('여명', 'Noun'),
#  ('의', 'Josa'),
#  ('교수', 'Noun'),
#  ('진', 'Noun'),
#  (',', 'Punctuation'),
#  ('300', 'Number'),
#  ('여명', 'Noun'),
#  ('의', 'Josa'),
#  ('직원', 'Noun'),
#  (',', 'Punctuation'),
#  ('8100', 'Number'),
#  ('여명', 'Noun'),
#  ('의', 'Josa'),
#  ('재학생', 'Noun'),
#  ('이', 'Josa'),
#  ('혼연', 'Noun'),
#  ('일체', 'Noun'),
#  ('되어', 'Verb'),
#  ('내실', 'Verb'),
#  ('있는', 'Adjective'),
#  ('대학', 'Noun'),
#  ('으로', 'Josa'),
#  ('발전', 'Noun'),
#  ('하고', 'Josa'),
#  ('있습니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('특히', 'Adverb'),
#  ('2007년', 'Number'),
#  ('원', 'Modifier'),
#  ('주', 'Modifier'),
#  ('대학', 'Noun'),
#  ('과의', 'Josa'),
#  ('통합', 'Noun'),
#  ('을', 'Josa'),
#  ('계기', 'Noun'),
#  ('로', 'Josa'),
#  ('환', 'Noun'),
#  ('동해', 'Noun'),
#  ('권', 'Suffix'),
#  ('의', 'Josa'),
#  ('중심', 'Noun'),
#  ('대학', 'Noun'),
#  ('을', 'Josa'),
#  ('뛰어넘어', 'Verb'),
#  ('우리나라', 'Noun'),
#  ('중부', 'Noun'),
#  ('권', 'Suffix'),
#  ('핵심', 'Noun'),
#  ('대학', 'Noun'),
#  ('으로', 'Josa'),
#  ('발', 'Noun'),
#  ('돋', 'Verb'),
#  ('움', 'Noun'),
#  ('하고', 'Josa'),
#  ('있습니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('끊임없는', 'Adjective'),
#  ('변화', 'Noun'),
#  ('의', 'Josa'),
#  ('노력', 'Noun'),
#  ('으로', 'Josa'),
#  ('알찬', 'Adjective'),
#  ('국립', 'Noun'),
#  ('대학교', 'Noun'),
#  ('를', 'Josa'),
#  ('만', 'Noun'),
#  ('들어갑니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('우리', 'Noun'),
#  ('대학', 'Noun'),
#  ('은', 'Josa'),
#  ('대학교육', 'Noun'),
#  ('협의', 'Noun'),
#  ('회', 'Noun'),
#  ('에서', 'Josa'),
#  ('발표', 'Noun'),
#  ('하는', 'Verb'),
#  ('‘', 'Foreign'),
#  ('2018년', 'Number'),
#  ('국', 'Noun'),
#  ('·', 'Punctuation'),
#  ('공립', 'Noun'),
#  ('대학교', 'Noun'),
#  ('주요', 'Noun'),
#  ('공시', 'Noun'),
#  ('지표', 'Noun'),
#  ('’', 'Punctuation'),
#  ('가운데', 'Noun'),
#  ('28', 'Number'),
#  ('개교', 'Noun'),
#  ('의', 'Josa'),
#  ('국', 'Noun'),
#  ('·', 'Punctuation'),
#  ('공립', 'Noun'),
#  ('대학교', 'Noun'),
#  ('중', 'Noun'),
#  ('전임', 'Noun'),
#  ('교원', 'Noun'),
#  ('1', 'Number'),
#  ('인당', 'Verb'),
#  ('저', 'Determiner'),
#  ('역서', 'Noun'),
#  ('실적', 'Noun'),
#  ('1', 'Number'),
#  ('위', 'Noun'),
#  (',', 'Punctuation'),
#  ('전임', 'Noun'),
#  ('교원', 'Noun'),
#  ('1', 'Number'),
#  ('인당', 'Verb'),
#  ('학생', 'Noun'),
#  ('수', 'Noun'),
#  ('5', 'Number'),
#  ('위', 'Noun'),
#  (',', 'Punctuation'),
#  ('기숙사', 'Noun'),
#  ('수용률', 'Noun'),
#  ('6', 'Number'),
#  ('위', 'Noun'),
#  (',', 'Punctuation'),
#  ('학생', 'Noun'),
#  ('1', 'Number'),
#  ('인당', 'Verb'),
#  ('장서', 'Noun'),
#  ('수', 'Noun'),
#  ('6', 'Number'),
#  ('위', 'Noun'),
#  (',', 'Punctuation'),
#  ('전임', 'Noun'),
#  ('교원', 'Noun'),
#  ('확보', 'Noun'),
#  ('율', 'Noun'),
#  ('9', 'Number'),
#  ('위', 'Noun'),
#  ('에', 'Josa'),
#  ('기록', 'Noun'),
#  ('되는', 'Verb'),
#  ('등', 'Noun'),
#  ('내실을', 'Verb'),
#  ('기하', 'Noun'),
#  ('며', 'Josa'),
#  ('알차게', 'Adjective'),
#  ('발전', 'Noun'),
#  ('하는', 'Verb'),
#  ('대학', 'Noun'),
#  ('입니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('지역', 'Noun'),
#  ('발전', 'Noun'),
#  ('과', 'Josa'),
#  ('지역', 'Noun'),
#  ('인재', 'Noun'),
#  ('양성', 'Noun'),
#  ('을', 'Josa'),
#  ('선도', 'Noun'),
#  ('하기', 'Verb'),
#  ('위해', 'Noun'),
#  ('산학', 'Noun'),
#  ('협력', 'Noun'),
#  ('을', 'Josa'),
#  ('강화하고', 'Adjective'),
#  ('있습니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('2012년', 'Number'),
#  ('부터', 'Foreign'),
#  ('5년', 'Number'),
#  ('차', 'Foreign'),
#  ('사업인', 'Noun'),
#  ('산학', 'Noun'),
#  ('협력', 'Noun'),
#  ('선도', 'Noun'),
#  ('대학', 'Noun'),
#  ('육성', 'Noun'),
#  ('사업', 'Noun'),
#  ('단', 'Noun'),
#  ('을', 'Josa'),
#  ('성공', 'Noun'),
#  ('적', 'Suffix'),
#  ('으로', 'Josa'),
#  ('운영', 'Noun'),
#  ('한', 'Josa'),
#  ('바', 'Noun'),
#  ('있으며', 'Adjective'),
#  (',', 'Punctuation'),
#  ('2017년', 'Number'),
#  ('부터', 'Foreign'),
#  ('그', 'Noun'),
#  ('후속', 'Noun'),
#  ('사업인', 'Noun'),
#  ('사회', 'Noun'),
#  ('맞춤', 'Noun'),
#  ('형', 'Suffix'),
#  ('산학', 'Noun'),
#  ('협력', 'Noun'),
#  ('선도', 'Noun'),
#  ('대학', 'Noun'),
#  ('사업', 'Noun'),
#  ('단', 'Noun'),
#  ('(', 'Punctuation'),
#  ('LINC', 'Alpha'),
#  ('+)', 'Punctuation'),
#  ('을', 'Josa'),
#  ('운영', 'Noun'),
#  ('하고', 'Josa'),
#  ('있습니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('2012년', 'Number'),
#  ('부터', 'Foreign'),
#  ('10년', 'Number'),
#  ('간', 'Foreign'),
#  ('재정', 'Noun'),
#  ('지원', 'Noun'),
#  ('을', 'Josa'),
#  ('받는', 'Verb'),
#  ('2', 'Number'),
#  ('단계', 'Noun'),
#  ('공학', 'Noun'),
#  ('교육', 'Noun'),
#  ('혁신', 'Noun'),
#  ('센터', 'Noun'),
#  ('지원', 'Noun'),
#  ('사업', 'Noun'),
#  ('선정', 'Noun'),
#  (',', 'Punctuation'),
#  ('2014년', 'Number'),
#  ('국립', 'Noun'),
#  ('대학', 'Noun'),
#  ('육성', 'Noun'),
#  ('사업', 'Noun'),
#  ('에', 'Josa'),
#  ('선정', 'Noun'),
#  (',', 'Punctuation'),
#  ('특히', 'Adverb'),
#  ('2018년', 'Number'),
#  ('2', 'Number'),
#  ('주기', 'Noun'),
#  ('대학', 'Noun'),
#  ('기', 'Modifier'),
#  ('본', 'Modifier'),
#  ('역량', 'Noun'),
#  ('진단', 'Noun'),
#  ('에서', 'Josa'),
#  ('자율', 'Noun'),
#  ('개선', 'Noun'),
#  ('대학', 'Noun'),
#  ('으로', 'Josa'),
#  ('선정', 'Noun'),
#  ('되었습니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('이를', 'Verb'),
#  ('통해', 'Noun'),
#  ('우리', 'Noun'),
#  ('대학교', 'Noun'),
#  ('는', 'Josa'),
#  ('맞춤', 'Noun'),
#  ('형', 'Suffix'),
#  ('산학', 'Noun'),
#  ('협력', 'Noun'),
#  (',', 'Punctuation'),
#  ('대학', 'Noun'),
#  ('재정', 'Noun'),
#  ('자립', 'Noun'),
#  ('도', 'Josa'),
#  ('제', 'Noun'),
#  ('고', 'Josa'),
#  (',', 'Punctuation'),
#  ('학생', 'Noun'),
#  ('교육', 'Noun'),
#  ('수', 'Modifier'),
#  ('월성', 'Noun'),
#  ('확보', 'Noun'),
#  ('에', 'Josa'),
#  ('이바지', 'Noun'),
#  ('하고', 'Josa'),
#  ('있습니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('창의', 'Noun'),
#  ('적', 'Suffix'),
#  ('학문', 'Noun'),
#  ('연구', 'Noun'),
#  ('와', 'Josa'),
#  ('인간', 'Noun'),
#  ('존중', 'Noun'),
#  ('교육', 'Noun'),
#  ('으로', 'Josa'),
#  ('참된', 'Adjective'),
#  ('지성인', 'Noun'),
#  ('을', 'Josa'),
#  ('기릅니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('강릉원주대', 'Noun'),
#  ('학교', 'Noun'),
#  ('는', 'Josa'),
#  ('창의', 'Noun'),
#  ('적', 'Suffix'),
#  ('학문', 'Noun'),
#  ('연구', 'Noun'),
#  ('와', 'Josa'),
#  ('인간', 'Noun'),
#  ('존중', 'Noun'),
#  ('교육', 'Noun'),
#  ('을', 'Josa'),
#  ('통해', 'Noun'),
#  ('역량', 'Noun'),
#  ('과', 'Josa'),
#  ('인성', 'Noun'),
#  ('을', 'Josa'),
#  ('갖춘', 'Verb'),
#  ('인재', 'Noun'),
#  ('를', 'Josa'),
#  ('양성', 'Noun'),
#  ('하고', 'Josa'),
#  ('지역', 'Noun'),
#  ('발전', 'Noun'),
#  ('을', 'Josa'),
#  ('견인', 'Noun'),
#  ('하여', 'Verb'),
#  ('국가', 'Noun'),
#  ('와', 'Josa'),
#  ('인류', 'Noun'),
#  ('에', 'Josa'),
#  ('공', 'Modifier'),
#  ('헌', 'Modifier'),
#  ('함', 'Noun'),
#  ('을', 'Josa'),
#  ('최고', 'Noun'),
#  ('의', 'Josa'),
#  ('사명', 'Noun'),
#  ('으로', 'Josa'),
#  ('여기', 'Noun'),
#  ('고', 'Josa'),
#  ('있습니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('대학', 'Noun'),
#  ('은', 'Josa'),
#  ('교육', 'Noun'),
#  ('은', 'Josa'),
#  ('전', 'Modifier'),
#  ('공교육', 'Noun'),
#  ('뿐', 'Suffix'),
#  ('만', 'Josa'),
#  ('아니라', 'Adjective'),
#  (',', 'Punctuation'),
#  ('올바른', 'Adjective'),
#  ('인성', 'Noun'),
#  ('을', 'Josa'),
#  ('길러내는', 'Verb'),
#  ('교육', 'Noun'),
#  ('이', 'Josa'),
#  ('매우', 'Noun'),
#  ('중요합니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('우리', 'Noun'),
#  ('대학', 'Noun'),
#  ('은', 'Josa'),
#  ('전', 'Modifier'),
#  ('공교육', 'Noun'),
#  ('이외', 'Noun'),
#  ('에도', 'Josa'),
#  ('비교', 'Noun'),
#  ('과', 'Josa'),
#  ('교육', 'Noun'),
#  ('을', 'Josa'),
#  ('내실', 'Verb'),
#  ('있게', 'Adjective'),
#  ('편성', 'Noun'),
#  ('하여', 'Verb'),
#  ('역량', 'Noun'),
#  ('과', 'Josa'),
#  ('인성', 'Noun'),
#  ('을', 'Josa'),
#  ('갖추고', 'Verb'),
#  ('미래', 'Noun'),
#  ('의', 'Josa'),
#  ('꿈', 'Noun'),
#  ('을', 'Josa'),
#  ('향', 'Noun'),
#  ('해', 'Verb'),
#  ('도전', 'Noun'),
#  ('하는', 'Verb'),
#  ('참된', 'Adjective'),
#  ('지성인', 'Noun'),
#  ('을', 'Josa'),
#  ('양성', 'Noun'),
#  ('하는데', 'Verb'),
#  ('역량', 'Noun'),
#  ('을', 'Josa'),
#  ('집중', 'Noun'),
#  ('하고', 'Josa'),
#  ('있습니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('강릉원주대', 'Noun'),
#  ('학교', 'Noun'),
#  ('의', 'Josa'),
#  ('중심', 'Noun'),
#  ('은', 'Josa'),
#  ('학생', 'Noun'),
#  ('입니다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('자랑스러운', 'Adjective'),
#  ('대학', 'Noun'),
#  ('!', 'Punctuation'),
#  ('행복한', 'Adjective'),
#  ('학생', 'Noun'),
#  ('!', 'Punctuation'),
#  ('강릉', 'Noun'),
#  ('원', 'Modifier'),
#  ('주인', 'Noun'),
#  ('의', 'Josa'),
#  ('꿈', 'Noun'),
#  ('이', 'Josa'),
#  ('더', 'Noun'),
#  ('넓은', 'Adjective'),
#  ('세계', 'Noun'),
#  ('와', 'Josa'),
#  ('만나도록', 'Verb'),
#  (',', 'Punctuation'),
#  ('강릉', 'Noun'),
#  ('원', 'Modifier'),
#  ('주인', 'Noun'),
#  ('의', 'Josa'),
#  ('열정', 'Noun'),
#  ('이', 'Josa'),
#  ('더', 'Noun'),
#  ('밝은', 'Verb'),
#  ('미래', 'Noun'),
#  ('와', 'Josa'),
#  ('마주', 'Noun'),
#  ('하도록', 'Verb'),
#  ('강릉원주대', 'Noun'),
#  ('학', 'Noun'),
#  ('이', 'Josa'),
#  ('함께', 'Adverb'),
#  ('하겠습니다', 'Verb'),
#  ('.', 'Punctuation'),
#  ('\n', 'Foreign'),
#  ('감사합니다', 'Verb'),
#  ('.', 'Punctuation')]

# %%
b = t.morphs(text)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
vect = CountVectorizer()

# %%
text1 = text[0]

# %%
vect.fit(text1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-01b0521f956e> in <module>()
# ----> 1 vect.fit(text1)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py in fit(self, raw_documents, y)
#    1022         self
#    1023         """
# -> 1024         self.fit_transform(raw_documents)
#    1025         return self
#    1026
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#    1046         if isinstance(raw_documents, str):
#    1047             raise ValueError(
# -> 1048                 "Iterable over raw text documents expected, "
#    1049                 "string object received.")
#    1050
#
# ValueError: Iterable over raw text documents expected, string object received.

# %%
text[3]
# Out:
# '주'

# %%
text = list(text)

# %%
bow = vect.transform(b)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-59-0e91e8b52fd6> in <module>()
# ----> 1 bow = vect.transform(b)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py in transform(self, raw_documents)
#    1107             self._validate_vocabulary()
#    1108
# -> 1109         self._check_vocabulary()
#    1110
#    1111         # use the same matrix-building strategy as fit_transform
#
# /usr/local/lib/python3.6/dist-packages/sklearn/feature_extraction/text.py in _check_vocabulary(self)
#     387         """Check if vocabulary is empty or missing (not fit-ed)"""
#     388         msg = "%(name)s - Vocabulary wasn't fitted."
# --> 389         check_is_fitted(self, 'vocabulary_', msg=msg),
#     390
#     391         if len(self.vocabulary_) == 0:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     912
#     913     if not all_or_any([hasattr(estimator, attr) for attr in attributes]):
# --> 914         raise NotFittedError(msg % {'name': type(estimator).__name__})
#     915
#     916
#
# NotFittedError: CountVectorizer - Vocabulary wasn't fitted.
